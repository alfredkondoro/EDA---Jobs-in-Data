# %% [markdown]
# 1. What is the distribution of work experience levels?
# 2. How are salaries distributed across different experience levels?
# 3. What are the most common job titles in the dataset?
# 4. How does job category distribution look like?
# 5. What is the most common employment type (full-time, part-time, contract)?
# 6. How are salaries distributed across different job categories?
# 7. Which work settings are most common among data professionals?
# 8. What is the geographic distribution of companies?
# 9. How does company size impact salaries and job titles?
# 10. What is the overall salary distribution in the dataset?
# 11. How has the number of work years evolved over time?
# 12. Are there any correlations between variables?
# 13. How does the distribution of employee residence locations look like?
# 14. What is the distribution of salary currencies, and how does it relate to job locations?
# 15. Are there outliers in the salary data?

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/jobs-in-data/jobs_in_data.csv")
df.head(5)
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.shape
# Out:
# (9355, 12)

# %%
# !pip install sweetviz
# Out:
# ...
#   Obtaining dependency information for sweetviz from https://files.pythonhosted.org/packages/89/50/8d3f7ca820267a38b42c64778db0f186d85cec6e3f0c5210eab9c16e783f/sweetviz-2.3.1-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 37.0 MB/s eta 0:00:00
# ...

# %%
   import sweetviz as sv
   my_report = sv.analyze(df)
   my_report.show_notebook(w="100%", h="full") # if working in Kaggle
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="2404" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
